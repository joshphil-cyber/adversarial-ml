# %% [markdown]
# <a href="https://colab.research.google.com/github/joshphil-cyber/adversarial-ml/blob/main/01_fgsm_attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive (for saving results persistently)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/joshphil-cyber/adversarial-ml
# Out:
# Cloning into 'adversarial-ml'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 5.67 KiB | 5.67 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd adversarial-ml
# Out:
# /content/adversarial-ml

# %%
# %ls
# Out:
# README.md

# %%
# !git config --global user.email "jphilip3804@gmail.com"
# !git config --global user.name "joshphil-cyber"

# %%
# !git add .

# %%
# !git commit -m "first commit to test if it works from Google Colab"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !pip install adversarial-robustness-toolbox[pytorch] -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.1 MB/s eta 0:00:00

# %%
import torch
import torchvision
from art.attacks.evasion import FastGradientMethod
from art.estimators.classification import PyTorchClassifier

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("ART imported successfully!")
print("CUDA available:", torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# PyTorch version: 2.10.0+cu128
# Torchvision version: 0.25.0+cu128
# ART imported successfully!
# CUDA available: True
# Using device: cuda

# %%
# !git add .

# %%
# !git commit -m "successfully imported libraries"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
